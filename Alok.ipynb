# %%
Username=input("Enter your Username:")
Password=input("Enter your Password:")
print("Username", Username)
print("Password", "x" *len(Password))
# Out:
# Enter your Username: Alok
# Enter your Password: Password
# Username Alok
# Password xxxxxxxx
